# %%
import pynasdaq as nas;

# %% [markdown]
# #### Company list for a given exchange (nyse, nasdaq, amex)

# %%
#nasdaq changed their api end point
#nas.companyList(exchange="nasdaq").head()

# %% [markdown]
# # Stock

# %% [markdown]
# #### Current price of a stock

# %%
nas.currentPrice("AMZN")
# Out:
# symbol                                    AMZN
# company          Amazon.com, Inc. Common Stock
# lastSalePrice                          1837.53
# dtype: object

# %% [markdown]
# #### Stock summary quote

# %%
nas.stockSummaryQuote("IBM")
# Out:
#   Symbol CurrentPrice 1 Year Target   Today's High / Low Share Volume  \
# 0    IBM      $151.36         152.5  $ 151.41 / $ 150.10    2,904,494
#
#   90 Day Avg. Daily Volume Previous Close   52 Week High / Low  \
# 0                3,512,355       $ 150.39  $ 154.36 / $ 105.94
#
#         Market Cap P/E Ratio Forward P/E (1y) Earnings Per Share (EPS)  \
# 0  134,202,265,257     15.64            10.83                   $ 9.68
#
#   Annualized Dividend Ex Dividend Date Dividend Payment Date Current Yield  \
# 0              $ 6.48         5/9/2019             6/10/2019        4.32 %
#
#    Beta
# 0  1.05

# %% [markdown]
# #### Historical stock prices

# %%
#TODO: need to change api
#nas.historicalStockQuote('ibm','5d')

# %% [markdown]
# #### Batch quotes

# %%
nas.batchQuotes(['AAPL','GOOG',"FB","IBM"])
# Out:
#   symbol                                        companyName lastSalePrice  \
# 0   AAPL                            Apple Inc. Common Stock       $218.75
# 1   GOOG                Alphabet Inc. Class C Capital Stock     $1,239.56
# 2     FB                Facebook, Inc. Class A Common Stock       $187.19
# 3    IBM  International Business Machines Corporation Co...       $143.67
#
#   netChange percentageChange deltaIndicator       lastTradeTimestamp  \
# 0    -4.335            1.94%           down  DATA AS OF Sep 13, 2019
# 1     +5.31            0.43%             up  DATA AS OF Sep 13, 2019
# 2     -0.28            0.15%           down  DATA AS OF Sep 13, 2019
# 3     +0.05            0.03%             up  DATA AS OF Sep 13, 2019
#
#        volume
# 0  39,755,504
# 1   1,301,238
# 2  11,440,216
# 3   2,185,777

# %% [markdown]
# # Dividend

# %% [markdown]
# #### Dividend calendar for a given date

# %%
nas.dividendCalendar(date="2019-09-13").head()
# Out:
#                                          companyName symbol dividend_Ex_Date  \
# 0                                   Alamos Gold Inc.    AGI       09/13/2019
# 1                                       Allegion plc   ALLE       09/13/2019
# 2         AllianzGI Equity & Convertible Income Fund    NIE       09/13/2019
# 3  AllianzGI NFJ Dividend, Interest & Premium Str...    NFJ       09/13/2019
# 4                                       Altria Group     MO       09/13/2019
#
#   payment_Date record_Date  dividend_Rate  indicated_Annual_Dividend  \
# 0   09/30/2019  09/16/2019          0.010                      0.040
# 1   09/30/2019  09/16/2019          0.270                      1.080
# 2   09/27/2019  09/16/2019          0.380                      1.900
# 3   09/27/2019  09/16/2019          0.225                      1.125
# 4   10/10/2019  09/16/2019          0.840                      3.360
#
#   announcement_Date
# 0        08/29/2019
# 1        09/05/2019
# 2        09/06/2019
# ...

# %% [markdown]
# #### List of high yield dividend stocks

# %%
nas.highYieldDividendStocks().head(n=10)
# Out:
#                                      Name  LastSale  annualdividend  \
# Symbol
# MMLP       Martin Midstream Partners L.P.    5.8500        1.000000
# PTMN    Portman Ridge Finance Corporation    2.3001        0.400000
# TRMT               Tremont Mortgage Trust    4.8400        0.880000
# MDRR       Medalist Diversified REIT Inc.    4.4081        0.700000
# ABDC               Alcentra Capital Corp.    8.3800        0.720000
# OXLC            Oxford Lane Capital Corp.   10.6300        1.620000
# CEY                 Victory Portfolios II   24.1399        3.415704
# CMFN                       CM Finance Inc    7.3100        1.000000
# GMLP                Golar LNG Partners LP   11.9500        1.616800
# GPP              Green Plains Partners LP   14.3900        1.900000
#
#         dividendyield exdividenddate dividendpaymentdate
# Symbol
# MMLP          18.4843     05/07/2019          05/15/2019
# PTMN          17.5439     04/04/2019          04/26/2019
# ...

# %% [markdown]
# #### Dividend history for a company given the symbol

# %%
nas.dividendHistory("AAPL").head()
# Out:
#   exOrEffDate  type amount declarationDate  recordDate paymentDate
# 0  08/09/2019  Cash  $0.77      07/30/2019  08/12/2019  08/15/2019
# 1  05/10/2019  Cash  $0.77      04/30/2019  05/13/2019  05/16/2019
# 2  02/08/2019  Cash  $0.73      01/29/2019  02/11/2019  02/14/2019
# 3  11/08/2018  Cash  $0.73      11/01/2018  11/12/2018  11/15/2018
# 4  08/10/2018  Cash  $0.73      07/31/2018  08/13/2018  08/16/2018
